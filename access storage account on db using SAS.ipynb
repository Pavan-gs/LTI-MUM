# %%
blob_account_name = "pvnstore8"
blob_container_name = "mydata"
blob_relative_path = "churn.csv"
blob_sas_token = r"sp=rwd&st=2025-02-20T11:00:21Z&se=2025-02-20T19:00:21Z&spr=https&sv=2022-11-02&sr=b&sig=GK5ludLwIxQ3KM2AYcEzjyC38Fqu4%2F9ZMBdlggvwgSM%3D"

# %%
# Allow SPARK to read from Blob remotely
wasbs_path = 'wasbs://%s@%s.blob.core.windows.net/%s' %(blob_container_name,blob_account_name,blob_relative_path)
spark.conf.set('fs.azure.sas.%s.%s.blob.core.windows.net' %(blob_container_name, blob_account_name),blob_sas_token)
print('Remote blob path: ' + wasbs_path)
# Out:
# Remote blob path: wasbs://mydata@pvnstore8.blob.core.windows.net/churn.csv

# %%
df = spark.read.csv(wasbs_path, inferSchema=True, header=True)

# %%
df.count()
# Out:
# 10000

# %%
df.createOrReplaceTempView("source")

# %%
display(spark.sql('SELECT Geography, avg(EstimatedSalary), count(Exited) FROM SOURCE group by Geography'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Geography</th><th>avg(EstimatedSalary)</th><th>count(Exited)</th></tr></thead><tbody><tr><td>Germany</td><td>101113.4351016342</td><td>2509</td></tr><tr><td>France</td><td>99899.18081372172</td><td>5014</td></tr><tr><td>Spain</td><td>99440.57228098497</td><td>2477</td></tr></tbody></table></div>

# %%
df1=spark.sql('SELECT Geography, avg(EstimatedSalary), count(Exited) FROM SOURCE group by Geography')

# %%
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Geography</th><th>avg(EstimatedSalary)</th><th>count(Exited)</th></tr></thead><tbody><tr><td>Germany</td><td>101113.4351016342</td><td>2509</td></tr><tr><td>France</td><td>99899.18081372172</td><td>5014</td></tr><tr><td>Spain</td><td>99440.57228098497</td><td>2477</td></tr></tbody></table></div>

# %%
file1="df2.parquet"

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
sas_container = r"sp=rwdlm&st=2025-02-20T11:13:05Z&se=2025-02-20T19:13:05Z&spr=https&sv=2022-11-02&sr=c&sig=XW2eu4sIGq%2Bel4si3%2FSPakoEITwYK7c2%2F430cxq8uL8%3D"

# %%
spark.conf.set('fs.azure.sas.%s.%s.blob.core.windows.net' %(blob_container_name, blob_account_name),sas_container)

# %%
df1.write.mode("overwrite").format("parquet").save(path='wasbs://%s@%s.blob.core.windows.net/%s' %(blob_container_name,blob_account_name,file1))
